# %%
# Importando as bibliotecas 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Cria varriável df para o armazenar o DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/danielvieira95/Inteligencia_Artificial_2025/refs/heads/main/bases_de_dados/monitoramento_tempo.csv')

# %%
# Exibe as quatro primeiras linhas do DataFrame
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
# Exibe as quatro últimas linhas do DataFrame
df.tail()
# Out:
#        temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 45248       282.00   1031.0      81.0              50.0                  2.0
# 45249       282.89   1030.0      71.0             330.0                  1.0
# 45250       283.39   1030.0      71.0             290.0                  1.0
# 45251       283.02   1029.0      71.0             290.0                  2.0
# 45252       282.28   1029.0      76.0             340.0                  1.0
#
#       dia_da_semana                 data
# 45248         Terça  2017-11-29 20:00:00
# 45249         Terça  2017-11-29 21:00:00
# 45250         Terça  2017-11-29 22:00:00
# 45251         Terça  2017-11-29 23:00:00
# 45252        Quarta  2017-11-30 00:00:00

# %%
# Importa a biblioteca datetime para fazer a conversão dos dados de data de objeto para datetime
import datetime
df['data'] = pd.to_datetime(df['data'])

# %%
df.info() # Exibe informações sobre a Base de Dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
plt.plot(df['data'], df['temperatura']) # Plota o gráfico de linha da temperatura em função do tempo

# %%
# Criando código para plotar um gráfico dentro do outro
fig = plt.figure(figsize=(12,5)) # Cria uma figura com tamanho 12x5
eixo = fig.add_axes([0, 0, 1, 1]) # Cria os eixos da figura
eixo.set_ylim(200,500) # Define o limite do eixo y
eixo.plot(df['data'], df['temperatura'], color='blue') # Plota o gráfico de linha da temperatura em função do tempo
eixo.grid(True) # Adiciona a grade ao gráfico

# Definindo o período do gráfico 
eixo.set_xlim(datetime.datetime(2014, 4, 1), datetime.datetime(2014, 6, 1)) # Define o período do gráfico
eixo.set_title('Temperatura em função do tempo', fontsize = 16, pad = 20) # Define o título do gráfico
eixo.set_xlabel('Data', fontsize = 14) # Define o rótulo do eixo x
eixo.set_ylabel('Temperatura', fontsize = 14) # Define o rótulo do eixo y
eixo.legend() # Adiciona a legenda ao gráfico

# Criando o Eixo 2
eixo2 = fig.add_axes([0.35, 0.50, 0.5, 0.3]) # Cria o eixo 2 para o gráfico
# Limites do eixo x
eixo2.xaxis.set_major_locator(mdates.DayLocator(interval = 7)) # Define o número máximo de valores no eixo x
eixo2.xaxis.set_major_formatter(mdates.DateFormatter('%d-%b')) # Define o formato dos valores do eixo x
eixo2.set_xlim(datetime.datetime(2015, 4, 1), datetime.datetime(2015, 5, 1)) # Define o período do gráfico
eixo2.tick_params(axis='x', labelsize = 8) # Rotaciona os valores do eixo x em 45 graus
eixo2.plot(df['data'], df['temperatura'], color='red') # Plota o gráfico de linha da temperatura em função do tempo
eixo2.grid(True) # Adiciona a grade ao gráfico
eixo2.set_title('Temperatura em função do tempo', fontsize = 10, pad = 10) # Define o título do gráfico
eixo2.legend(['Temperatura'], loc = 'best', fontsize = 10) # Adiciona a legenda ao gráfico
# Out:
# C:\Users\dsadm\AppData\Local\Temp\ipykernel_5924\1307537435.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   eixo.legend() # Adiciona a legenda ao gráfico

# %%
# 
fig = plt.figure(figsize=(15,8)) # Cria uma figura com tamanho 15x8
plt.rcParams['font.size'] = 10 # Define o tamanho da fonte
eixo = fig.add_axes([0, 0, 1, 1]) # Cria os eixos da figura
eixo.set_ylim(200,500) # Define o limite do eixo y
eixo2 = fig.add_axes([0.65, 0.58, 0.3, 0.3]) # Cria o eixo 2 para o gráfico
eixo.plot(df['data'], df['temperatura'], color='blue') # Plota o gráfico de linha da temperatura em função do tempo
eixo.grid(True) # Adiciona a grade ao gráfico

# Definindo o período do gráfico    
eixo.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2014, 6, 1)) # Define o período do gráfico
eixo.set_title('Temperatura em função do tempo', fontsize = 16, pad = 20) # Define o título do gráfico
eixo.set_xlabel('Data', fontsize = 14) # Define o rótulo do eixo x
eixo.set_ylabel('Temperatura', fontsize = 14) # Define o rótulo do eixo y
eixo.legend(['Temperatura'], loc = 'best') # Adiciona a legenda ao gráfico
azul_esquerda = df ['data'] < datetime.datetime(2014, 5, 1) # Cria a variável azul_esquerda para armazenar os valores menores que 15/05/2014
azul_direita = df ['data'] > datetime.datetime(2014, 6, 1) # Cria a variável azul_direita para armazenar os valores maiores que 15/06/2014

# Eixo 2 
eixo2.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 5, 1)) # Define o período do gráfico
eixo2.plot(df['data'], df['temperatura'], color='blue') # Plota o gráfico de linha da temperatura em função do tempo
eixo2.plot(df['data'], df['temperatura'], color='red') # Plota o gráfico de linha da temperatura em função do tempo
eixo2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'], color='blue') # Plota o gráfico de linha da temperatura em função do tempo
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color='blue') # Plota o gráfico de linha da temperatura em função do tempo
eixo2.grid(True) # Adiciona a grade ao gráfico
eixo2.set_title('Temperatura 05/2014', fontsize = 10, pad = 10) # Define o título do gráfico
eixo2.set_xlabel('Mês', fontsize = 10) # Define o rótulo do eixo x
eixo2.set_ylabel('Temperatura', fontsize = 10) # Define o rótulo do eixo y
eixo2.tick_params(axis='x', labelsize = 8) # Rotaciona os valores do eixo x em 45 graus

# %%
# Realizando anotações no gráfico
fig = plt.figure(figsize=(15,5)) # Cria uma figura com tamanho 15x8
eixo = fig.add_axes([0, 0, 1, 1]) # Cria os eixos da figura
eixo.plot(df['data'], df['temperatura'], color='blue') # Plota o gráfico de linha da temperatura em função do tempo
eixo.grid(True) # Adiciona a grade ao gráfico
eixo.set_title('Temperatura em função do tempo', fontsize = 16, pad = 20) # Define o título do gráfico
eixo.set_xlabel('Data', fontsize = 14) # Define o rótulo do eixo x
eixo.set_ylabel('Temperatura', fontsize = 14) # Define o rótulo do eixo y
eixo.legend(['Temperatura'], loc = 'best') # Adiciona a legenda ao gráfico

# Fazendo as marcações no gráfico
eixo.axhline(max(df['temperatura']), color='red', linestyle='--') # Adiciona uma linha horizontal no valor máximo da temperatura
eixo.axhline(min(df['temperatura']), color='green', linestyle='--') # Adiciona uma linha horizontal no valor mínimo da temperatura

# Armazenando valores em x1
x1 = df['data'][df['temperatura'].idxmax()] # Armazena em x1 a data do valor máximo da temperatura
y1 = max(df['temperatura']) # Armazena em y1 o valor máximo da temperatura
eixo.annotate('Máx: {}'.format(y1), xy=(x1, y1), xytext=(x1, y1+5), arrowprops=dict(facecolor='black', shrink=0.03)) # Adiciona uma anotação no gráfico para o valor máximo da temperatura 
x2 = df['data'][df['temperatura'].idxmin()] # Armazena em x2 a data do valor mínimo da temperatura
y2 = min(df['temperatura']) # Armazena em y2 o valor mínimo da temperatura
eixo.annotate('Mín: {}'.format(y2), xy=(x2, y2), xytext=(x2, y2-7), arrowprops=dict(facecolor='black', shrink=0.03)) # Adiciona uma anotação no gráfico para o valor mínimo da temperatura
# Out:
# Text(2013-12-08 13:00:00, 255.37, 'Mín: 262.37')
