# %%
#Aula Machine Learning - 2025
# %pip install pandas numpy matplotlib scikit-learn seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns   
from sklearn.linear_model import LinearRegression
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Dados de treinamento
vazao = np.array ([10, 20, 30, 5, 35, 40]).reshape((-1, 1)) #Vazão de água (m³/s)
nivel = np.array ([50, 60, 70, 45, 80, 85]) #Nível de água (m)

#Criando o modelo de regressão linear
modelo = LinearRegression()
modelo.fit(vazao, nivel)
# Out:
# LinearRegression()

# %%
#Dados de teste
vazao_teste = np.array([15, 25, 33]).reshape((-1, 1))
vazao_teste = np.array([5, 2, 7, 30, 50]).reshape((-1, 1))
nivel_predito = modelo.predict(vazao_teste)

# %%
#Imprime as previsões
for i in range(len(vazao_teste)):
    print(f'Vazão: {vazao_teste[i][0]} m³/s -> Nível Predito: {nivel_predito[i]:.2f} m')

plt.scatter(vazao, nivel, color='blue', label='Dados de Treinamento')
plt.scatter(vazao_teste, nivel_predito, color='red', label='Previsões')
plt.plot(vazao, modelo.predict(vazao), color='green', label='Modelo de Regressão')
plt.xlabel('Vazão (m³/s)')  
plt.ylabel('Nível (m)')
plt.title('Regressão Linear: Vazão vs Nível de Água')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Vazão: 5 m³/s -> Nível Predito: 44.03 m
# Vazão: 2 m³/s -> Nível Predito: 40.59 m
# Vazão: 7 m³/s -> Nível Predito: 46.31 m
# Vazão: 30 m³/s -> Nível Predito: 72.63 m
# Vazão: 50 m³/s -> Nível Predito: 95.51 m

# %%
#Regressão Polinomial
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
#Dados fornecidos
Q = np.array([100, 200, 300, 500, 600, 700, 400]).reshape((-1, 1)) #Vazão de água (m³/s)
T = np.array([30, 35, 40, 45, 60, 100, 150]) #Temperatura (°C)

# %%
#Modelo 1 Regressão Linear Simples
modelo_linear = LinearRegression()
modelo_linear.fit(Q,T)
T_pred_linear = modelo_linear.predict(Q)
print("Previsões Regressão Linear:", T_pred_linear)
# Out:
# Previsões Regressão Linear: [37.32142857 46.78571429 56.25       75.17857143 84.64285714 94.10714286
#  65.71428571]

# %%
#Modelo 2 Regressão Polinomial Grau 2
poly = PolynomialFeatures(degree=2)
Q_poly = poly.fit_transform(Q)
poly_model = LinearRegression()
poly_model.fit(Q_poly, T)

# Geração de valores para curvas
Q_range = np.linspace(100, 700, 500).reshape(-1, 1)
T_linear_curve = modelo_linear.predict(Q_range)
T_poly_curve = poly_model.predict(poly.transform(Q_range))

#Plotagem do gráfico com modelos de machine learning
plt.figure(figsize=(10, 6))
plt.scatter(Q, T, color='blue', label='Dados Reais')
plt.plot(Q, T_pred_linear, color='red', label='Regressão Linear')
plt.plot(Q_range, T_poly_curve, color='green', label='Regressão Polinomial Grau 2')
plt.xlabel('Vazão de Água (m³/s)')  
plt.ylabel('Temperatura (°C)')
plt.title('Modelos de Regressão: Linear vs Polinomial Grau 2')
plt.legend()
plt.grid(True)
plt.show()
