# %%
#Importação das bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Realiza a leitura do arquivo CSV
df = pd.read_csv('basededados/monitoramento_tempo.csv', sep = ',')

# %%
#Exibe as primeiras linhas do dataframe
df.head() #Exibe as quatro primeiras linhas
# Out:
#    Temperatura  Pressão  Umidade  Direção do Vento  Velocidade do Vento  \
# 0   282.080000   1024.0     81.0               0.0                  0.0
# 1   282.080000   1024.0     81.0               0.0                  0.0
# 2   282.083252   1024.0     80.0               4.0                  0.0
# 3   282.091866   1024.0     80.0              18.0                  0.0
# 4   282.100481   1024.0     80.0              31.0                  0.0
#
#   Dia Da Semana                 Data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Temperatura          45253 non-null  float64
#  1   Pressão              45253 non-null  float64
#  2   Umidade              45253 non-null  float64
#  3   Direção do Vento     45253 non-null  float64
#  4   Velocidade do Vento  45253 non-null  float64
#  5   Dia Da Semana        45253 non-null  object
#  6   Data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
import datetime 
df['Data'] = pd.to_datetime(df['Data'])
#Transforma a data de objeto em datetime 
plt.plot(df['Data'], df ['Temperatura'])
plt.figure(figsize = (15,8))
plt.xlabel('Data e Hora')
plt.ylabel('Temperatura')
plt.show()

# %%
fig = plt.Figure(figsize = (15, 8))  # Cria uma figura
eixo = fig.add_axes([0, 0, 1, 1])  # Adiciona os eixos

eixo.plot(df['Data'], df['Temperatura'] / 10, color='red', lw=0.7)  # Corrigido aqui
eixo.set_title('Temperatura no momento', fontsize=12)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.set_xlabel('Ano', fontsize=14)
eixo.set_ylabel('Ano', fontsize=14)
# Out:
# Text(0, 0.5, 'Ano')

# %%
#Selecionando o período da base de dados
fig = plt.figure(figsize=(15,8))
plt.rcParams['font.size'] = '20'
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df['Data'], df['Temperatura'], color= 'black')
eixo.set_xlim(datetime.datetime(2015, 1, 1), datetime.datetime(2015, 12, 31)) #Xlim define o valor inicial e o valor final 
eixo.set_title('Temperatura - Ano 2015', fontsize = 25)
eixo.legend(['Temperatura'], fontsize = 20)
eixo.set_xlabel('Ano', fontsize = 20)
plt.xticks(rotation = 45, fontsize = 15, ha = 'right') #Ajusta o espaçamento da legenda
plt.show()
